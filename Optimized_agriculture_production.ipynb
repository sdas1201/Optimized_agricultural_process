# %% [markdown]
# <a href="https://colab.research.google.com/github/sdas1201/Optimized_agricultural_process/blob/main/Optimized_agriculture_production.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#for  manipulation
import numpy as np;
import pandas as pd;

#for data visualizations
import matplotlib.pyplot as plt;
import seaborn as sns;

#for interactivity
from ipywidgets import interact;

# %%
#lets read the dataset
data = pd.read_csv('/content/Crop_recommendation.csv')

# %%
#check the data shape
print("Shape of  the data :", data.shape);
# Out:
# Shape of  the data : (2200, 8)

# %%
#lets check the head of the data
data.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_9076322732529457423 = autoviz.get_registered_df('df_9076322732529457423')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
# ...

# %%
#lets check if there is any missing value present in it or not
data.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %% [markdown]
# 1) Fill-NA function is used to replace these missing values with statistical values such as mean median or mode
# 2) NA means Not Available
# 3) Pandas have functions like fill-NA,drop-NA to treat missing values.

# %%
#lets check the crop present in the dataset
data['label'].value_counts()
# Out:
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: label, dtype: int64

# %%
#lets check the summary for all the crops

print("Average ratio of N in soil : {0:.2f}".format(data['N'].mean()))
print("Average ratio of P in soil : {0:.2f}".format(data['P'].mean()))
print("Average ratio of K in soil : {0:.2f}".format(data['K'].mean()))
print("Average Temp in celcius : {0:.2f}".format(data['temperature'].mean()))
print("Average Relative humidity in % : {0:.2f}".format(data['humidity'].mean()))
print("Average ph value in soil : {0:.2f}".format(data['ph'].mean()))
print("Average Rainfall in soil : {0:.2f}".format(data['rainfall'].mean()))
# Out:
# Average ratio of N in soil : 50.55
# Average ratio of P in soil : 53.36
# Average ratio of K in soil : 48.15
# Average Temp in celcius : 25.62
# Average Relative humidity in % : 71.48
# Average ph value in soil : 6.47
# Average Rainfall in soil : 103.46

# %%
#lets check the overall activity of each crop
@interact
def summary(crops = list(data["label"].value_counts().index)):
    x= data[data['label']== crops];
    print("----------------------------");
    print("Statictics for nitrogen");
    print("Minimum Nitrogen required:- ",x['N'].min());
    print("Average Nirogen required:- ",x['N'].mean());
    print("Maximum Nitrogen required:- ",x['N'].max());
    print("----------------------------");
    print("Statictics for phosphorous");
    print("Minimum phosphorous required:- ",x['P'].min());
    print("Average phosphorous required:- ",x['P'].mean());
    print("Maximum phosphorous required:- ",x['P'].max());
    print("----------------------------");
    print("Statictics for potassium");
    print("Minimum pottasium required:- ",x['K'].min());
    print("Average potassium required:- ",x['K'].mean());
    print("Maximum potassium required:- ",x['K'].max());
    print("----------------------------");
    print("Statictics for temperature");
    print("Minimum temperature required:- {0:.2f}",format(x['temperature'].min()));
    print("Average temperature required:- {0:.2f}",format(x['temperature'].mean()));
    print("Maximum temperature required:- {0:.2f}",format(x['temperature'].max()));
    print("----------------------------");
    print("Statictics for humidity");
    print("Minimum humidity required:- {0:.2f}",format(x['humidity'].min()));
    print("Average humidity required:- {0:.2f}",format(x['humidity'].mean()));
    print("Maximum humidity required:- {0:.2f}",format(x['humidity'].max()));
    print("----------------------------");
    print("Statictics for ph");
    print("Minimum ph required:- {0:.2f}",format(x['ph'].min()));
    print("Average ph required:- {0:.2f}",format(x['ph'].mean()));
    print("Maximum ph required:- {0:.2f}",format(x['ph'].max()));
    print("----------------------------");
    print("Statictics for rainfall");
    print("Minimum rainfall required:- {0:.2f}",format(x['rainfall'].min()));
    print("Average rainfall required:- {0:.2f}",format(x['rainfall'].mean()));
    print("Maximum rainfall required:- {0:.2f}",format(x['rainfall'].max()));

# %%
#compare the average requirement for each crops with average condition
@interact
def compare(conditions=['N','P','K','ph','humidity','rainfall']):
    print("Average value for ",conditions,"is {0:.2f}".format(data[conditions].mean()))
    print("-------------------------------------");
    print("rice : {0:.2f}".format(data[(data['label']=='rice')][conditions].mean()));
    print("banana : {0:.2f}".format(data[(data['label']=='banana')][conditions].mean()));
    print("oranges : {0:.2f}".format(data[(data['label']=='orange')][conditions].mean()));
    print("maize: {0:.2f}".format(data[(data['label']=='maize')][conditions].mean()));
    print("jute : {0:.2f}".format(data[(data['label']=='jute')][conditions].mean()));
    print("cotton : {0:.2f}".format(data[(data['label']=='cotton')][conditions].mean()));
    print("coconut : {0:.2f}".format(data[(data['label']=='coconut')][conditions].mean()));
    print("papaya: {0:.2f}".format(data[(data['label']=='papaya')][conditions].mean()));
    print("apple : {0:.2f}".format(data[(data['label']=='apple')][conditions].mean()));
    print("muskmelon: {0:.2f}".format(data[(data['label']=='muskmelon')][conditions].mean()));
    print("watermelon : {0:.2f}".format(data[(data['label']=='watermelon')][conditions].mean()));
    print("grapes : {0:.2f}".format(data[(data['label']=='grapes')][conditions].mean()));
    print("mango : {0:.2f}".format(data[(data['label']=='mango')][conditions].mean()));
    print("pomegranate : {0:.2f}".format(data[(data['label']=='pomegranate')][conditions].mean()));
    print("lentil : {0:.2f}".format(data[(data['label']=='lentil')][conditions].mean()));
    print("blackgram: {0:.2f}".format(data[(data['label']=='blackgram')][conditions].mean()));
    print("mungbean : {0:.2f}".format(data[(data['label']=='mungbean')][conditions].mean()));
    print("monthbean : {0:.2f}".format(data[(data['label']=='monthbean')][conditions].mean()));
    print("pigeonpeas : {0:.2f}".format(data[(data['label']=='pigeonpeas')][conditions].mean()));
    print("kidneybeans: {0:.2f}".format(data[(data['label']=='kidneybeans')][conditions].mean()));
    print("chickpea : {0:.2f}".format(data[(data['label']=='chickpea')][conditions].mean()));
    print("coffee: {0:.2f}".format(data[(data['label']=='coffee')][conditions].mean()));
# Out:
# interactive(children=(Dropdown(description='conditions', options=('N', 'P', 'K', 'ph', 'humidity', 'rainfall')…

# %%
#lets make this function more intutive

@interact
def compare(conditions=['N','P','K','ph','humidity','rainfall']):
    print("Crops which require greater than average ",conditions, '\n');
    print(data[data[conditions]>data[conditions].mean()]['label'].unique())
    print("-------------------------------");
    print("Crops which require less than average ",conditions, '\n');
    print(data[data[conditions]<=data[conditions].mean()]['label'].unique())
# Out:
# interactive(children=(Dropdown(description='conditions', options=('N', 'P', 'K', 'ph', 'humidity', 'rainfall')…

# %%
#lets find out some interesting and unique patterns

print("Crop which require very High Ratio of Nitrogen Content in soil: ",data[data['N']>120]['label'].unique())
print("Crop which require very High Ratio of Phosphorous Content in soil: ",data[data['P']>100]['label'].unique())
print("Crop which require very High Ratio of potassium Content in soil: ",data[data['K']>200]['label'].unique())
print("Crop which require very High amt of rainfall : ",data[data['rainfall']>200]['label'].unique())
print("Crop which require very low temparature: ",data[data['temperature']<10]['label'].unique())
print("Crop which require very High Temp: ",data[data['temperature']>40]['label'].unique())
print("Crop which require low humidity : ",data[data['humidity']<20]['label'].unique())
print("Crop which require very low ph level: ",data[data['ph']<4]['label'].unique())
print("Crop which require very High ph level: ",data[data['ph']>9]['label'].unique())
# Out:
# Crop which require very High Ratio of Nitrogen Content in soil:  ['cotton']
# Crop which require very High Ratio of Phosphorous Content in soil:  ['grapes' 'apple']
# Crop which require very High Ratio of potassium Content in soil:  ['grapes' 'apple']
# Crop which require very High amt of rainfall :  ['rice' 'papaya' 'coconut']
# Crop which require very low temparature:  ['grapes']
# Crop which require very High Temp:  ['grapes' 'papaya']
# Crop which require low humidity :  ['chickpea' 'kidneybeans']
# Crop which require very low ph level:  ['mothbeans']
# Crop which require very High ph level:  ['mothbeans']

# %%
 #lets understand which crops can only be grown in summmer,winterand rainy season

print("Summer crops")
print(data[(data['temperature'] > 30) & (data['humidity'] > 50)]['label'].unique())
print("winter")
print(data[(data['temperature'] < 18) & (data['humidity'] > 30)]['label'].unique())
print("rainy crops")
print(data[(data['rainfall'] > 200) & (data['humidity'] > 30)]['label'].unique())
# Out:
# Summer crops
# ['pigeonpeas' 'mothbeans' 'blackgram' 'mango' 'grapes' 'orange' 'papaya']
# winter
# ['grapes' 'orange']
# rainy crops
# ['rice' 'papaya' 'coconut']

# %%
print("Distribution for Agriculture Condition")

plt.subplot(2,4,1)
sns.displot(data['N'],color= 'grey')
plt.xlabel('N level',fontsize=10)
plt.grid()
plt.suptitle("Distribution of agricultural condition",fontsize = 20)
plt.show()

plt.subplot(2,4,2)
sns.displot(data['P'],color= 'lightgreen')
plt.xlabel('P level',fontsize=10)
plt.grid()
plt.suptitle("Distribution of agricultural condition",fontsize = 20)
plt.show()

plt.subplot(2,4,3)
sns.displot(data['K'],color= 'black')
plt.xlabel('K level',fontsize=10)
plt.grid()
plt.suptitle("Distribution of agricultural condition",fontsize = 20)
plt.show()

plt.subplot(2,4,4)
sns.displot(data['rainfall'],color= 'blue')
plt.xlabel('rainfall level',fontsize=10)
plt.grid()
plt.suptitle("Distribution of agricultural condition",fontsize = 20)
plt.show()

plt.subplot(2,4,5)
sns.displot(data['ph'],color= 'red')
plt.xlabel('ph level',fontsize=10)
plt.grid()
plt.suptitle("Distribution of agricultural condition",fontsize = 20)
plt.show()

plt.subplot(2,4,6)
sns.displot(data['humidity'],color= 'black')
plt.xlabel('humidity level',fontsize=10)
plt.grid()

plt.suptitle("Distribution of agricultural condition",fontsize = 20)
plt.show()
# Out:
# Distribution for Agriculture Condition

# %%
 #Clusturing Analysis - making the data points into relevant group
 #k-means clustering algorithm

from sklearn.cluster import KMeans

#removing the label columns
x = data.drop(['label'], axis=1)

#selecting all  the values of the data
x = x.values

#checking the shapes
print(x.shape)
# Out:
# (2200, 7)

# %%
# let us see the number of clusters within the dataset

plt.rcParams['figure.figsize']=(10,4)

wcss = []
for i in range(1,11):
    km = KMeans(n_clusters = i , init = 'k-means++', max_iter = 300, n_init = 10,random_state = 0)
    km.fit(x)
    wcss.append(km.inertia_)

#lets plot the results
plt.plot(range(1,11),wcss)
plt.title('The Elbow Method',fontsize =20)
plt.xlabel('No of clusters')
plt.ylabel('wcss')
plt.show()

# %%
#lets implement k-mean algorithm
km = KMeans(n_clusters = 4, init = 'k-means++',max_iter = 300, n_init = 10, random_state = 0)
y_means = km.fit_predict(x)

#lets find out the result
a= data['label']
y_means = pd.DataFrame(y_means)
z = pd.concat([y_means,a],axis=1)
z = z.rename(columns = {0:'cluster'})

#lets check the clusters of each crops

print("Checking the results after applying the K-means Clustering Analysis \n")
print("Crops in first cluster: ",z[z['cluster']==0]['label'].unique())
print("----------------------------------")
print("Crops in second Cluster: ",z[z['cluster']==1]['label'].unique())
print("----------------------------------")
print("Crops in third Cluster: ",z[z['cluster']==2]['label'].unique())
print("----------------------------------")
print("Crops in forth Cluster: ",z[z['cluster']==3]['label'].unique())
print("----------------------------------")
# Out:
# Checking the results after applying the K-means Clustering Analysis
#
# Crops in first cluster:  ['maize' 'chickpea' 'kidneybeans' 'pigeonpeas' 'mothbeans' 'mungbean'
#  'blackgram' 'lentil' 'pomegranate' 'mango' 'orange' 'papaya' 'coconut']
# ----------------------------------
# Crops in second Cluster:  ['maize' 'banana' 'watermelon' 'muskmelon' 'papaya' 'cotton' 'coffee']
# ----------------------------------
# Crops in third Cluster:  ['grapes' 'apple']
# ----------------------------------
# Crops in forth Cluster:  ['rice' 'pigeonpeas' 'papaya' 'coconut' 'jute' 'coffee']
# ----------------------------------

# %%
#lets split the Dataset for Predictive Modelling

y= data['label']
x= data.drop(['label'],axis =1)

print("Shape of x:", x.shape)
print("Shape of y:", y.shape)
# Out:
# Shape of x: (2200, 7)
# Shape of y: (2200,)

# %%
#lets create trainning and testing set for validation of results
from sklearn.model_selection import train_test_split;

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)

print("The shape of x train: ", x_train.shape)
print("The shape of x test: ", x_test.shape)
print("The shape of y train: ", y_train.shape)
print("The shape of x test: ", x_test.shape)
# Out:
# The shape of x train:  (1540, 7)
# The shape of x test:  (660, 7)
# The shape of y train:  (1540,)
# The shape of x test:  (660, 7)

# %%
#lets create a predictive model

from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#lets Evaluate the model performance
from sklearn.metrics import confusion_matrix

#Lets print the confusion matrix first

plt.rcParams['figure.figsize'] = (10,10)
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot = True, cmap = 'Wistia')
plt.title("Confusion Matrix for Logistic Regression", fontsize = 15)
plt.show()

# %%
from sklearn.metrics import classification_report
#lets print the classification report also

cr = classification_report(y_test, y_pred);
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        28
#       banana       1.00      1.00      1.00        30
#    blackgram       0.84      0.87      0.86        31
#     chickpea       1.00      1.00      1.00        34
#      coconut       1.00      1.00      1.00        26
#       coffee       1.00      1.00      1.00        29
#       cotton       0.84      0.96      0.90        28
#       grapes       1.00      1.00      1.00        30
#         jute       0.83      0.94      0.88        31
#  kidneybeans       0.96      1.00      0.98        26
#       lentil       0.91      0.91      0.91        22
#        maize       0.92      0.81      0.86        27
#        mango       1.00      1.00      1.00        28
#    mothbeans       0.81      0.81      0.81        36
#     mungbean       1.00      0.97      0.98        29
#    muskmelon       1.00      1.00      1.00        30
# ...

# %%
data.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
prediction = model.predict((np.array([[90,
                                       40,
                                       40,
                                       20,
                                       80,
                                       7,
                                       200]])))
print("The suggested Crop for given Climatic Condition is : ", prediction)
# Out:
# The suggested Crop for given Climatic Condition is :  ['rice']
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
